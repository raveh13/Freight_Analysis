# %%
# === Librairies pour la manipulation et l'analyse de données ===
import os
from pathlib import Path
import pandas as pd
from datetime import datetime

# === Librairies pour la visualisation ===
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# === Librairies pour l'affichage interactif (Jupyter/IPython) ===
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option("display.width", None)

# %%
user = os.getlogin().lower()
print(f"Detected user: {user}")

# Use the default path only if the username is 'rabah'
if user == "rabah":
    file_path = r"A:\OneDrive - Sopex London Ltd\Shared\19. Shipments - Sopex\New_Freight_file_V1.xlsx"
    
else:
    # Fallback logic for other users
    file_path = ""
# Out:
# Detected user: rabah

# %%
df= pd.read_excel(file_path, sheet_name="Freight")

display(df.head())
print(df.columns.tolist())

freight= df[['Port POL', 'Country POD', 'Port POD', 
             'Freight', 'Freight_Currency', 'Surcharge', 'Surcharge_Currency', 
             'Freight All In', 'Extra', 'Unit', 'Extra_Currency', 'Terminal POL', 
             'Shipping Line', 
             'Shipping Line2', 'Free Time POL', 
             'Free Time POD', 'Validity', 'Standardized','Region']].copy()

display(freight.head())
print(freight.info())

EUR_USD = 1.1605

freight.loc[freight["Freight_Currency"] == "USD", "FREIGHT_USE_USD"] = freight["Freight"] * 1
freight.loc[freight["Freight_Currency"] == "EUR", "FREIGHT_USE_USD"] = freight["Freight"] * EUR_USD

freight.loc[freight["Surcharge_Currency"] == "USD", "Freight_Surcharge_USD"] = freight["Surcharge"] * 1
freight.loc[freight["Surcharge_Currency"] == "EUR", "Freight_Surcharge_USD"] = freight["Surcharge"] * EUR_USD

display(freight.head())
display(freight.info())
# Out:
#   Port POL Country POD       Port POD  Freight Freight_Currency  Surcharge  \
# 0   Santos    Tanzania  Dar Es Salaam     2800              USD        0.0
# 1   Santos       Benin        Cotonou     1665              USD        0.0
# 2   Santos         UAE      Jebel Ali     1775              USD        0.0
# 3   Santos      Turkey         Mersin     1350              USD        0.0
# 4   Santos       Ghana           Tema     1700              USD        0.0
#
#   Surcharge_Currency  Freight All In Extra Unit  ... FREIGHT_USE_USD  \
# 0                USD          2800.0   NaN  NaN  ...          2800.0
# 1                USD          1665.0   NaN  NaN  ...          1665.0
# 2                USD          1775.0   NaN  NaN  ...          1775.0
# 3                USD          1350.0   NaN  NaN  ...          1350.0
# 4                USD          1700.0   NaN  NaN  ...          1700.0
#
#   Freight_Surcharge FREIGHT_ALL_USD Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0               0.0          2800.0         NaN         NaN         NaN
# 1               0.0          1665.0         NaN         NaN         NaN
# 2               0.0          1775.0         NaN         NaN         NaN
# 3               0.0          1350.0         NaN         NaN         NaN
# 4               0.0          1700.0         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 EUR/USD  1.16
# 0         NaN         NaN     NaN   NaN
# 1         NaN         NaN     NaN   NaN
# 2         NaN         NaN     NaN   NaN
# 3         NaN         NaN     NaN   NaN
# 4         NaN         NaN     NaN   NaN
#
# [5 rows x 29 columns]
# ['Port POL', 'Country POD', 'Port POD', 'Freight', 'Freight_Currency', 'Surcharge', 'Surcharge_Currency', 'Freight All In', 'Extra', 'Unit', 'Extra_Currency', 'Terminal POL', 'Shipping Line', 'Shipping Line2', 'Free Time POL', 'Free Time POD', 'Validity', 'Standardized', 'Region', 'FREIGHT_USE_USD', 'Freight_Surcharge', 'FREIGHT_ALL_USD', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'EUR/USD', 1.16]

# %% [markdown]
# ### Working on valid dates

# %%
df_clean = freight.dropna(subset=['Standardized'])

latest = df_clean.loc[df_clean.groupby(['Port POL', 'Port POD'])['Standardized'].idxmax()]

from datetime import datetime
today = datetime.today()

# Make a real copy to avoid SettingWithCopyWarning
df_future = df_clean[df_clean['Standardized'] > today].copy()

display(df_future.head())
print(df_future.info())

# Convert Extra safely to numeric (float), no integer casting
df_future["Extra"] = pd.to_numeric(df_future["Extra"].fillna(0), errors="coerce")

#df_future["Extra"] = pd.to_numeric(df_future["Extra"], errors="coerce")

# Compute Extra in USD
df_future.loc[df_future["Extra_Currency"] == "USD", "Freight_Extra_USD"] = df_future["Extra"] * 1
df_future.loc[df_future["Extra_Currency"] == "EUR", "Freight_Extra_USD"] = df_future["Extra"] * EUR_USD

# print unit unique
print(df_future["Unit"].unique())


display(df_future.head())
print(df_future.info())

# Make sure Unit is lowercase and stripped
df_future["Unit"] = df_future["Unit"].astype(str).str.strip().str.lower()

# Create the column if it doesn't exist
#df_future["Freight_Extra_USD"] = pd.to_numeric(df_future["Freight_Extra_USD"], errors="coerce")

# Case 1: Unit = "bl" → divide by 240
df_future.loc[df_future["Unit"] == "bl", "Freight_Extra_USD"] = (df_future["Freight_Extra_USD"] / 240).round(0)

# Case 2: Unit = "cntr" → divide by 240
df_future.loc[df_future["Unit"] == "cntr", "Freight_Extra_USD"] = (df_future["Freight_Extra_USD"] / 240).round(0)

# Case 3: Unit = NaN → do nothing (automatically handled)

print(df_future.info())

df_future["Freight_All_In_USD"] = (df_future["FREIGHT_USE_USD"].fillna(0)+ df_future["Freight_Surcharge_USD"].fillna(0)
    + df_future["Freight_Extra_USD"].fillna(0)).round(0)


print(df_future.info(verbose=True))

schema = pd.DataFrame({
    "dtype": df_future.dtypes,
    "non_null": df_future.notna().sum(),
    "nulls": df_future.isna().sum()
})

display(schema)


display(df_future.head())

print(df_future.info())

obj_cols = df_future.select_dtypes(include='object').columns

df_future[obj_cols] = (
    df_future[obj_cols]
    .astype(str)                                   # convert everything to string
    .apply(lambda col: col.str.strip().str.lower())  # trim + lowercase
    .apply(lambda col: col.str.replace(r'\s+', ' ', regex=True))  # remove extra spaces
)
# Out:
#     Port POL Country POD Port POD  Freight Freight_Currency  Surcharge  \
# 981   Santos      Israel   Ashdod     1531              USD      116.0
# 982   Santos     Lebanon   Beirut     1811              USD      116.0
# 983   Santos     Albania   Durres     1531              USD      116.0
# 984   Santos      Turkey   Mersin     1631              USD      116.0
# 985   Santos     Senegal    Dakar     1511              USD      116.0
#
#     Surcharge_Currency  Freight All In Extra Unit Extra_Currency Terminal POL  \
# 981                USD          1647.0   NaN  NaN            NaN          BTP
# 982                USD          1927.0   NaN  NaN            NaN          BTP
# 983                USD          1647.0   NaN  NaN            NaN          BTP
# 984                USD          1747.0   NaN  NaN            NaN          BTP
# 985                USD          1627.0   NaN  NaN            NaN          BTP
#
#     Shipping Line Shipping Line2 Free Time POL Free Time POD  \
# 981        Monero            MSC            14            21
# 982        Monero            MSC            14            21
# 983        Monero            MSC            14            21
# 984        Monero            MSC            14            21
# 985        Monero            MSC            14            21
#
#                 Validity Standardized         Region  FREIGHT_USE_USD  \
# 981  2026-02-28 00:00:00   2026-02-28  Mediterranean           1531.0
# 982  2026-02-28 00:00:00   2026-02-28  Mediterranean           1811.0
# 983  2026-02-28 00:00:00   2026-02-28         Europe           1531.0
# 984  2026-02-28 00:00:00   2026-02-28  Mediterranean           1631.0
# 985  2026-02-28 00:00:00   2026-02-28    Africa West           1511.0
#
#      Freight_Surcharge_USD
# 981                  116.0
# 982                  116.0
# 983                  116.0
# 984                  116.0
# 985                  116.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 981 to 1061
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Port POL               81 non-null     object
#  1   Country POD            81 non-null     object
#  2   Port POD               81 non-null     object
#  3   Freight                81 non-null     int64
#  4   Freight_Currency       81 non-null     object
#  5   Surcharge              81 non-null     float64
#  6   Surcharge_Currency     80 non-null     object
#  7   Freight All In         81 non-null     float64
#  8   Extra                  12 non-null     object
#  9   Unit                   12 non-null     object
#  10  Extra_Currency         12 non-null     object
#  11  Terminal POL           34 non-null     object
#  12  Shipping Line          80 non-null     object
#  13  Shipping Line2         29 non-null     object
#  14  Free Time POL          41 non-null     object
#  15  Free Time POD          58 non-null     object
#  16  Validity               81 non-null     object
#  17  Standardized           81 non-null     datetime64[ns]
#  18  Region                 81 non-null     object
#  19  FREIGHT_USE_USD        81 non-null     float64
#  20  Freight_Surcharge_USD  80 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(15)
# memory usage: 13.9+ KB
# None

# %%
# Format date
today = datetime.today().strftime("%Y%m%d")

# Build full path + filename
path = r"A:\OneDrive - Sopex London Ltd\Shared\19. Shipments - Sopex"
filename = f"{today}_last_freight.xlsx"

full_path = f"{path}\\{filename}"

# Save
df_future.to_excel(full_path, index=False)

# %%
pivot = df_future.pivot_table(
    index=['Region','Country POD','Port POD'],
    columns='Port POL',
    values='Freight_All_In_USD',
    aggfunc='min'
)

pivot = pivot.sort_index().sort_index(axis=1)
pivot_reset = pivot.reset_index()
pivot_flat = pivot.reset_index().rename_axis(None, axis=1)

# Identify POL columns (all columns except the index columns)
pol_cols = ['antwerp', 'buenaventura', 'laem chabang', 'santos']

# Add cheapest freight value
pivot_flat['cheapest_freight'] = pivot_flat[pol_cols].min(axis=1)

# Add the POL (column name) where the freight is cheapest
pivot_flat['cheapest_pol'] = pivot_flat[pol_cols].idxmin(axis=1)

display(pivot_flat)
# Out:
#                         Region        Country POD       Port POD  antwerp  \
# 0                  africa west              benin        cotonou   1731.0
# 1                  africa west           cameroon         douala   1952.0
# 2                  africa west             gambia         banjul      NaN
# 3                  africa west              ghana           tema   1214.0
# 4                  africa west             guinea        conakry      NaN
# 5                  africa west        ivory coast        abidjan   1080.0
# 6                  africa west            liberia       monrovia      NaN
# 7                  africa west         mauritania     nouakchott      NaN
# 8                  africa west            senegal          dakar   1876.0
# 9                  africa west       sierra leone       capetown      NaN
# 10                 africa west       sierra leone       freetown      NaN
# 11                 africa west               togo           lome   1537.0
# 12                    americas           colombia      cartagena      NaN
# 13                    americas         costa rica           moin      NaN
# 14                    americas               peru         callao      NaN
# 15                      europe            albania         durres      NaN
# 16                      europe            belgium        antwerp      NaN
# 17                      europe            georgia           poti      NaN
# 18                      europe              italy          genoa      NaN
# 19  far east / south east asia           pakistan        karachi      NaN
# 20  far east / south east asia          singapore      singapore     18.0
# 21  far east / south east asia          sri lanka        colombo    491.0
# 22  far east / south east asia           thailand   laem chabang      NaN
# 23               mediterranean             israel         ashdod    698.0
# 24               mediterranean            lebanon         beirut   1261.0
# 25               mediterranean             turkey         mersin      NaN
# 26                 middle east            bahrain        bahrain    230.0
# 27                 middle east             jordan          aqaba      NaN
# 28                 middle east       saudi arabia         jeddah    463.0
# 29                 middle east                uae      jebel ali    447.0
# 30                 middle east              yemen     al mukalla      NaN
# 31                s & e africa           djibouti       djibouti   1661.0
# 32                s & e africa  equatorial guinea           bata      NaN
# 33                s & e africa              kenya        mombasa   1421.0
# 34                s & e africa         madagascar       tamatave    496.0
# 35                s & e africa           tanzania  dar es salaam   1755.0
# 36                s & e africa   trindad & tobago    point lisas      NaN
#
#     buenaventura  laem chabang  santos  cheapest_freight  cheapest_pol
# 0            NaN        1531.0  1527.0            1527.0        santos
# 1            NaN        2031.0  1977.0            1952.0       antwerp
# 2            NaN           NaN  1780.0            1780.0        santos
# 3            NaN        1599.0  1727.0            1214.0       antwerp
# 4            NaN        4982.0     NaN            4982.0  laem chabang
# 5            NaN        1531.0  1627.0            1080.0       antwerp
# 6            NaN           NaN  1850.0            1850.0        santos
# 7            NaN           NaN  1650.0            1650.0        santos
# 8            NaN        2781.0  1627.0            1627.0        santos
# 9            NaN           NaN  1650.0            1650.0        santos
# 10           NaN           NaN  1980.0            1980.0        santos
# 11           NaN        1531.0  1577.0            1531.0  laem chabang
# 12           NaN           NaN   860.0             860.0        santos
# 13           NaN           NaN  1330.0            1330.0        santos
# 14           NaN           NaN  1325.0            1325.0        santos
# 15           NaN        5225.0  1647.0            1647.0        santos
# 16        1053.0           NaN  1341.0            1053.0  buenaventura
# 17           NaN           NaN  1250.0            1250.0        santos
# 18         953.0           NaN     NaN             953.0  buenaventura
# 19           NaN        3009.0  1427.0            1427.0        santos
# 20           NaN         350.0   941.0              18.0       antwerp
# 21           NaN        1817.0  1141.0             491.0       antwerp
# 22           NaN           NaN  1041.0            1041.0        santos
# 23           NaN        3359.0  1647.0             698.0       antwerp
# 24           NaN        7730.0  1927.0            1261.0       antwerp
# 25           NaN        2800.0  1747.0            1747.0        santos
# 26           NaN        1050.0     NaN             230.0       antwerp
# 27           NaN        1792.0  1847.0            1792.0  laem chabang
# 28           NaN        1592.0     NaN             463.0       antwerp
# 29           NaN        1097.0  1527.0             447.0       antwerp
# 30           NaN           NaN  2527.0            2527.0        santos
# 31           NaN        4024.0  1977.0            1661.0       antwerp
# 32           NaN           NaN  1850.0            1850.0        santos
# 33           NaN        1791.0  1950.0            1421.0       antwerp
# 34           NaN           NaN  1927.0             496.0       antwerp
# 35           NaN        1991.0  2077.0            1755.0       antwerp
# 36           NaN           NaN  1475.0            1475.0        santos

# %%
# Format date
today = datetime.today().strftime("%Y%m%d")

# Build full path + filename
path = r"A:\OneDrive - Sopex London Ltd\Shared\19. Shipments - Sopex"
filename = f"{today}_last_freight.xlsx"

full_path = f"{path}\\{filename}"

# Save
df_future.to_excel(full_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[39], line 13
#      10 full_path = f"{path}\\{filename}"
#      12 # Save
# ---> 13 df_future.to_excel(full_path, index=False)
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)
#    2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:204, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     201 if mode == "a":
#     202     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 204 super().__init__(
#     205     path,
#     206     engine=engine,
#     207     date_format=date_format,
#     208     datetime_format=datetime_format,
#     209     mode=mode,
#     210     storage_options=storage_options,
#     211     if_sheet_exists=if_sheet_exists,
#     212     engine_kwargs=engine_kwargs,
#     213 )
#     215 try:
#     216     self._book = Workbook(self._handles.handle, **engine_kwargs)  # type: ignore[arg-type]
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File c:\Users\belar\.conda\envs\tradingenv\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'A:\\OneDrive - Sopex London Ltd\\Shared\\19. Shipments - Sopex\\20260202_last_freight.xlsx'
